# %% [markdown]
# # <span style="font-width:bold; font-size: 3rem; color:#1EB182;"> **Air Quality** </span><span style="font-width:bold; font-size: 3rem; color:#333;">- Part 04: Batch Inference</span>
#
# ## 🗒️ This notebook is divided into the following sections:
#
# 1. Download model and batch inference data
# 2. Make predictions, generate PNG for forecast
# 3. Store predictions in a monitoring feature group adn generate PNG for hindcast

# %% [markdown]
# ## <span style='color:#ff5f27'> 📝 Imports

# %%
import datetime
import pandas as pd
from xgboost import XGBRegressor
import hopsworks
import json
from functions import util
import os

# %%
today = datetime.datetime.now() - datetime.timedelta(0)
tomorrow = today + datetime.timedelta(days = 1)
today
# Out:
# datetime.datetime(2024, 11, 13, 16, 57, 59, 451497)

# %% [markdown]
# ## <span style="color:#ff5f27;"> 📡 Connect to Hopsworks Feature Store </span>

# %%
# os.environ["HOPSWORKS_API_KEY"] = open("../../data/hopsworks-api-key.txt", 'r').read().rstrip()

project = hopsworks.login()
fs = project.get_feature_store() 

secrets = util.secrets_api(project.name)
location_str = secrets.get_secret("SENSOR_LOCATION_JSON").value
location = json.loads(location_str)
country=location['country']
city=location['city']
street=location['street']
# Out:
# Connected. Call `.close()` to terminate connection gracefully.
#
# Logged in to project, explore it here https://c.app.hopsworks.ai:443/p/1164449
# 2024-11-13 16:58:02,327 WARNING: using legacy validation callback
# Connected. Call `.close()` to terminate connection gracefully.
# Connected. Call `.close()` to terminate connection gracefully.

# %% [markdown]
# ## <span style="color:#ff5f27;"> ⚙️ Feature View Retrieval</span>

# %%
feature_view = fs.get_feature_view(
    name='air_quality_fv',
    version=1,
)

# %% [markdown]
# ## <span style="color:#ff5f27;">🪝 Download the model from Model Registry</span>

# %%
mr = project.get_model_registry()
model_version = 2
retrieved_model = mr.get_model(
    name="air_quality_xgboost_model",
    version=model_version,
)

# Download the saved model artifacts to a local directory
saved_model_dir = retrieved_model.download()
# Out:
# Connected. Call `.close()` to terminate connection gracefully.
# Downloading model artifact (1 dirs, 5 files)... DONE

# %%
# Loading the XGBoost regressor model and label encoder from the saved model directory
# retrieved_xgboost_model = joblib.load(saved_model_dir + "/xgboost_regressor.pkl")
retrieved_xgboost_model = XGBRegressor()

retrieved_xgboost_model.load_model(saved_model_dir + "/model.json")

# Displaying the retrieved XGBoost regressor model
retrieved_xgboost_model
# Out:
# XGBRegressor(base_score='2.4250517E1', booster='gbtree', callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None,
#              feature_types=['float', 'float', 'float', 'float', 'float',
#                             'float', 'float'],
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %% [markdown]
# ## <span style="color:#ff5f27;">✨ Get Weather Forecast Features with Feature View   </span>

# %%
weather_fg = fs.get_feature_group(
    name='weather',
    version=1,
)
batch_data = weather_fg.filter(weather_fg.date >= today).read().sort_values(by=['date'])
batch_data
# Out:
# Finished: Reading data from Hopsworks, using Hopsworks Feature Query Service (0.68s)
#                        date  temperature_2m_mean  precipitation_sum  \
# 7 2024-11-14 00:00:00+00:00                 6.00                0.0
# 6 2024-11-15 00:00:00+00:00                 6.85                0.0
# 0 2024-11-16 00:00:00+00:00                10.10                0.0
# 2 2024-11-17 00:00:00+00:00                 5.00                0.6
# 4 2024-11-18 00:00:00+00:00                 4.60                0.0
# 5 2024-11-19 00:00:00+00:00                 1.45                0.0
# 8 2024-11-20 00:00:00+00:00                 3.30                1.4
# 1 2024-11-21 00:00:00+00:00                 6.90                1.1
# 3 2024-11-22 00:00:00+00:00                 1.50                1.8
#
#    wind_speed_10m_max  wind_direction_10m_dominant       city
# 7           15.124284                   321.766113  stockholm
# 6            9.470120                   261.253906  stockholm
# 0           25.809765                   239.858688  stockholm
# 2           20.371038                   223.567963  stockholm
# 4           14.044615                   268.531219  stockholm
# 5            4.334974                   311.633453  stockholm
# 8           23.402769                    89.118622  stockholm
# 1           11.367109                   259.045990  stockholm
# 3           30.302078                   256.954346  stockholm

# %%
aq_fg = fs.get_feature_group(
    name='air_quality',
    version=1,
)
date_before = today - datetime.timedelta(days = 3)
pm25_before = aq_fg.select(['date', 'pm25']).filter(aq_fg.date >= date_before).read().sort_values(by=['date'])
# Out:
# Finished: Reading data from Hopsworks, using Hopsworks Feature Query Service (0.70s)

# %%
pm25_before
# Out:
#                        date  pm25
# 1 2024-11-11 00:00:00+00:00  20.0
# 2 2024-11-12 00:00:00+00:00  21.0
# 0 2024-11-13 00:00:00+00:00  14.0

# %%
pm25_before = pm25_before['pm25'].tolist()

# %%
pm25_before
# Out:
# [20.0, 21.0, 14.0]

# %%
predicted_pm25 = []
for index, row in batch_data.iterrows():
    row['pm25_1'] = pm25_before[2]
    row['pm25_2'] = pm25_before[1]
    row['pm25_3'] = pm25_before[0]
    pred = retrieved_xgboost_model.predict([row[['temperature_2m_mean', 'precipitation_sum', 'wind_speed_10m_max', 'wind_direction_10m_dominant', \
                                                              'pm25_1', 'pm25_2', 'pm25_3']]])[0]
    predicted_pm25.append(pred)
    pm25_before.pop(0)
    pm25_before.append(pred)
print(predicted_pm25)
# Out:
# [16.371897, 21.275959, 19.38199, 17.278856, 18.946526, 26.166904, 25.239416, 35.43066, 16.089363]

# %% [markdown]
# ### <span style="color:#ff5f27;">🤖 Making the predictions</span>

# %%
if model_version == 2:
    batch_data['predicted_pm25'] = predicted_pm25
else:
    batch_data['predicted_pm25'] = retrieved_xgboost_model.predict(
    batch_data[['temperature_2m_mean', 'precipitation_sum', 'wind_speed_10m_max', 'wind_direction_10m_dominant']])
batch_data
# Out:
#                        date  temperature_2m_mean  precipitation_sum  \
# 7 2024-11-14 00:00:00+00:00                 6.00                0.0
# 6 2024-11-15 00:00:00+00:00                 6.85                0.0
# 0 2024-11-16 00:00:00+00:00                10.10                0.0
# 2 2024-11-17 00:00:00+00:00                 5.00                0.6
# 4 2024-11-18 00:00:00+00:00                 4.60                0.0
# 5 2024-11-19 00:00:00+00:00                 1.45                0.0
# 8 2024-11-20 00:00:00+00:00                 3.30                1.4
# 1 2024-11-21 00:00:00+00:00                 6.90                1.1
# 3 2024-11-22 00:00:00+00:00                 1.50                1.8
#
#    wind_speed_10m_max  wind_direction_10m_dominant       city  predicted_pm25
# 7           15.124284                   321.766113  stockholm       16.371897
# 6            9.470120                   261.253906  stockholm       21.275959
# 0           25.809765                   239.858688  stockholm       19.381990
# 2           20.371038                   223.567963  stockholm       17.278856
# 4           14.044615                   268.531219  stockholm       18.946526
# 5            4.334974                   311.633453  stockholm       26.166904
# 8           23.402769                    89.118622  stockholm       25.239416
# 1           11.367109                   259.045990  stockholm       35.430660
# 3           30.302078                   256.954346  stockholm       16.089363

# %%
batch_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9 entries, 7 to 3
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   date                         9 non-null      datetime64[us, UTC]
#  1   temperature_2m_mean          9 non-null      float32
#  2   precipitation_sum            9 non-null      float32
#  3   wind_speed_10m_max           9 non-null      float32
#  4   wind_direction_10m_dominant  9 non-null      float32
#  5   city                         9 non-null      object
#  6   predicted_pm25               9 non-null      float32
# dtypes: datetime64[us, UTC](1), float32(5), object(1)
# memory usage: 396.0+ bytes

# %% [markdown]
# ### <span style="color:#ff5f27;">🤖 Saving the predictions (for monitoring) to a Feature Group</span>

# %%
batch_data['street'] = street
batch_data['city'] = city
batch_data['country'] = country
# Fill in the number of days before the date on which you made the forecast (base_date)
batch_data = batch_data.sort_values(by=['date'])
batch_data['days_before_forecast_day'] = range(1, len(batch_data)+1)
batch_data
# Out:
#                        date  temperature_2m_mean  precipitation_sum  \
# 7 2024-11-14 00:00:00+00:00                 6.00                0.0
# 6 2024-11-15 00:00:00+00:00                 6.85                0.0
# 0 2024-11-16 00:00:00+00:00                10.10                0.0
# 2 2024-11-17 00:00:00+00:00                 5.00                0.6
# 4 2024-11-18 00:00:00+00:00                 4.60                0.0
# 5 2024-11-19 00:00:00+00:00                 1.45                0.0
# 8 2024-11-20 00:00:00+00:00                 3.30                1.4
# 1 2024-11-21 00:00:00+00:00                 6.90                1.1
# 3 2024-11-22 00:00:00+00:00                 1.50                1.8
#
#    wind_speed_10m_max  wind_direction_10m_dominant       city  predicted_pm25  \
# 7           15.124284                   321.766113  stockholm       16.371897
# 6            9.470120                   261.253906  stockholm       21.275959
# 0           25.809765                   239.858688  stockholm       19.381990
# 2           20.371038                   223.567963  stockholm       17.278856
# 4           14.044615                   268.531219  stockholm       18.946526
# 5            4.334974                   311.633453  stockholm       26.166904
# 8           23.402769                    89.118622  stockholm       25.239416
# 1           11.367109                   259.045990  stockholm       35.430660
# 3           30.302078                   256.954346  stockholm       16.089363
#
#                                    street country  days_before_forecast_day
# 7  stockholm-st eriksgatan 83-air-quality  sweden                         1
# 6  stockholm-st eriksgatan 83-air-quality  sweden                         2
# 0  stockholm-st eriksgatan 83-air-quality  sweden                         3
# 2  stockholm-st eriksgatan 83-air-quality  sweden                         4
# 4  stockholm-st eriksgatan 83-air-quality  sweden                         5
# 5  stockholm-st eriksgatan 83-air-quality  sweden                         6
# 8  stockholm-st eriksgatan 83-air-quality  sweden                         7
# 1  stockholm-st eriksgatan 83-air-quality  sweden                         8
# 3  stockholm-st eriksgatan 83-air-quality  sweden                         9

# %%
batch_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9 entries, 7 to 3
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   date                         9 non-null      datetime64[us, UTC]
#  1   temperature_2m_mean          9 non-null      float32
#  2   precipitation_sum            9 non-null      float32
#  3   wind_speed_10m_max           9 non-null      float32
#  4   wind_direction_10m_dominant  9 non-null      float32
#  5   city                         9 non-null      object
#  6   predicted_pm25               9 non-null      float32
#  7   street                       9 non-null      object
#  8   country                      9 non-null      object
#  9   days_before_forecast_day     9 non-null      int64
# dtypes: datetime64[us, UTC](1), float32(5), int64(1), object(3)
# memory usage: 612.0+ bytes

# %% [markdown]
# ### Create Forecast Graph
# Draw a graph of the predictions with dates as a PNG and save it to the github repo
# Show it on github pages

# %%
file_path = "../../docs/air-quality/assets/img/pm25_forecast.png"
plt = util.plot_air_quality_forecast(city, street, batch_data, file_path)
plt.show()
# Out:
# 2024-11-13 17:17:56,313 WARNING: DeprecationWarning: backend2gui is deprecated since IPython 8.24, backends are managed in matplotlib and can be externally registered.

# %%
# Get or create feature group
monitor_fg = fs.get_or_create_feature_group(
    name='aq_predictions',
    description='Air Quality prediction monitoring',
    version=1,
    primary_key=['city','street','date','days_before_forecast_day'],
    event_time="date"
)

# %%
monitor_fg.insert(batch_data, write_options={"wait_for_job": True})
# Out:
# Feature Group created successfully, explore it at
# https://c.app.hopsworks.ai:443/p/1164449/fs/1155152/fg/1346994
# Uploading Dataframe: 0.00% |          | Rows 0/9 | Elapsed Time: 00:00 | Remaining Time: ?
# Launching job: aq_predictions_1_offline_fg_materialization
# Job started successfully, you can follow the progress at
# https://c.app.hopsworks.ai/p/1164449/jobs/named/aq_predictions_1_offline_fg_materialization/executions
# (<hsfs.core.job.Job at 0x7f8c1c5067e0>, None)

# %%
# We will create a hindcast chart for  only the forecasts made 1 day beforehand
monitoring_df = monitor_fg.filter(monitor_fg.days_before_forecast_day == 1).read()
monitoring_df
# Out:
# Finished: Reading data from Hopsworks, using Hopsworks Feature Query Service (0.62s)
#                        date  temperature_2m_mean  precipitation_sum  \
# 0 2024-11-14 00:00:00+00:00                  6.0                0.0
#
#    wind_speed_10m_max  wind_direction_10m_dominant       city  predicted_pm25  \
# 0           15.124284                   321.766113  stockholm       16.371897
#
#                                    street country  days_before_forecast_day
# 0  stockholm-st eriksgatan 83-air-quality  sweden                         1

# %%
air_quality_fg = fs.get_feature_group(
    name='air_quality',
    version=1,
)
air_quality_df = air_quality_fg.read()
air_quality_df
# Out:
# Finished: Reading data from Hopsworks, using Hopsworks Feature Query Service (1.13s)
#                           date  pm25 country       city  \
# 0    2020-07-05 00:00:00+00:00  15.0  sweden  stockholm
# 1    2018-12-25 00:00:00+00:00  24.0  sweden  stockholm
# 2    2020-01-05 00:00:00+00:00  17.0  sweden  stockholm
# 3    2024-03-26 00:00:00+00:00  21.0  sweden  stockholm
# 4    2021-08-17 00:00:00+00:00  17.0  sweden  stockholm
# ...                        ...   ...     ...        ...
# 2179 2018-06-16 00:00:00+00:00  28.0  sweden  stockholm
# 2180 2020-09-18 00:00:00+00:00  15.0  sweden  stockholm
# 2181 2023-12-04 00:00:00+00:00  19.0  sweden  stockholm
# 2182 2024-09-03 00:00:00+00:00  12.0  sweden  stockholm
# 2183 2021-10-01 00:00:00+00:00  13.0  sweden  stockholm
#
#                                       street  \
# 0     stockholm-st eriksgatan 83-air-quality
# 1     stockholm-st eriksgatan 83-air-quality
# 2     stockholm-st eriksgatan 83-air-quality
# 3     stockholm-st eriksgatan 83-air-quality
# 4     stockholm-st eriksgatan 83-air-quality
# ...                                      ...
# 2179  stockholm-st eriksgatan 83-air-quality
# 2180  stockholm-st eriksgatan 83-air-quality
# 2181  stockholm-st eriksgatan 83-air-quality
# 2182  stockholm-st eriksgatan 83-air-quality
# 2183  stockholm-st eriksgatan 83-air-quality
#
#                                     url
# 0     https://api.waqi.info/feed/@10523
# 1     https://api.waqi.info/feed/@10523
# 2     https://api.waqi.info/feed/@10523
# 3     https://api.waqi.info/feed/@10523
# 4     https://api.waqi.info/feed/@10523
# ...                                 ...
# 2179  https://api.waqi.info/feed/@10523
# 2180  https://api.waqi.info/feed/@10523
# 2181  https://api.waqi.info/feed/@10523
# 2182  https://api.waqi.info/feed/@10523
# 2183  https://api.waqi.info/feed/@10523
#
# [2184 rows x 6 columns]

# %%
outcome_df = air_quality_df[['date', 'pm25']]
preds_df =  monitoring_df[['date', 'predicted_pm25']]

hindcast_df = pd.merge(preds_df, outcome_df, on="date")
hindcast_df = hindcast_df.sort_values(by=['date'])

# If there are no outcomes for predictions yet, generate some predictions/outcomes from existing data
if len(hindcast_df) == 0:
    hindcast_df = util.backfill_predictions_for_monitoring(weather_fg, air_quality_df, monitor_fg, retrieved_xgboost_model)
hindcast_df
# Out:
# Finished: Reading data from Hopsworks, using Hopsworks Feature Query Service (0.72s)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[91], line 9
#       7 # If there are no outcomes for predictions yet, generate some predictions/outcomes from existing data
#       8 if len(hindcast_df) == 0:
# ----> 9     hindcast_df = util.backfill_predictions_for_monitoring(weather_fg, air_quality_df, monitor_fg, retrieved_xgboost_model)
#      10 hindcast_df
#
# File /mnt/c/Users/KTH/Desktop/KTH/Scalable Machine Learning and Deep Learning - ID2223/mlfs-book/notebooks/ch03/functions/util.py:302, in backfill_predictions_for_monitoring(weather_fg, air_quality_df, monitor_fg, model)
#     300 features_df = features_df.sort_values(by=['date'], ascending=True)
#     301 features_df = features_df.tail(10)
# --> 302 features_df['predicted_pm25'] = model.predict(features_df[['temperature_2m_mean', 'precipitation_sum', 'wind_speed_10m_max', 'wind_direction_10m_dominant']])
#     303 df = pd.merge(features_df, air_quality_df[['date','pm25','street','country']], on="date")
#     304 df['days_before_forecast_day'] = 1
#
# File /mnt/c/Users/KTH/Desktop/KTH/Scalable Machine Learning and Deep Learning - ID2223/mlfs-book/.venv2/lib/python3.12/site-packages/xgboost/sklearn.py:1168, in XGBModel.predict(self, X, output_margin, validate_features, base_margin, iteration_range)
#    1166 if self._can_use_inplace_predict():
#    1167     try:
# -> 1168         predts = self.get_booster().inplace_predict(
#    1169             data=X,
#    1170             iteration_range=iteration_range,
#    1171             predict_type="margin" if output_margin else "value",
#    1172             missing=self.missing,
#    1173             base_margin=base_margin,
#    1174             validate_features=validate_features,
#    1175         )
#    1176         if _is_cupy_array(predts):
#    1177             import cupy  # pylint: disable=import-error
#
# File /mnt/c/Users/KTH/Desktop/KTH/Scalable Machine Learning and Deep Learning - ID2223/mlfs-book/.venv2/lib/python3.12/site-packages/xgboost/core.py:2418, in Booster.inplace_predict(self, data, iteration_range, predict_type, missing, validate_features, base_margin, strict_shape)
#    2416     data, fns, _ = _transform_pandas_df(data, enable_categorical)
#    2417     if validate_features:
# -> 2418         self._validate_features(fns)
#    2419 if _is_list(data) or _is_tuple(data):
#    2420     data = np.array(data)
#
# File /mnt/c/Users/KTH/Desktop/KTH/Scalable Machine Learning and Deep Learning - ID2223/mlfs-book/.venv2/lib/python3.12/site-packages/xgboost/core.py:2970, in Booster._validate_features(self, feature_names)
#    2964 if my_missing:
#    2965     msg += (
#    2966         "\ntraining data did not have the following fields: "
#    2967         + ", ".join(str(s) for s in my_missing)
#    2968     )
# -> 2970 raise ValueError(msg.format(self.feature_names, feature_names))
#
# ValueError: feature_names mismatch: ['temperature_2m_mean', 'precipitation_sum', 'wind_speed_10m_max', 'wind_direction_10m_dominant', 'pm25_1', 'pm25_2', 'pm25_3'] ['temperature_2m_mean', 'precipitation_sum', 'wind_speed_10m_max', 'wind_direction_10m_dominant']
# expected pm25_2, pm25_1, pm25_3 in input data

# %% [markdown]
# ### Plot the Hindcast comparing predicted with forecasted values (1-day prior forecast)
#
# __This graph will be empty to begin with - this is normal.__
#
# After a few days of predictions and observations, you will get data points in this graph.

# %%
file_path = "../../docs/air-quality/assets/img/pm25_hindcast_1day.png"
plt = util.plot_air_quality_forecast(city, street, hindcast_df, file_path, hindcast=True)
plt.show()

# %% [markdown]
# ---
